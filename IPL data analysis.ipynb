# %% [markdown]
# WE are summarize our Analysis on following point:

# %% [markdown]
# 1. Extracting And Loading The Data
# 2.Cleaning the data and removing the noise
# 3.Analyse the Data on different Parameter
# 4.Visualizing the important Statistical finding
# 5.Making the best team of 11 based on the ICC world CUp winning squad formation of winning team of the IPL. i,e how many batters,bowlers and allrounder should be included in the team.

# %%
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('IPLData.csv')

# %%
data
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# ...

# %%
data.describe()
# Out:
#            Capped  Matches_Played         Runs     Average  Strike_Rate  \
# count  235.000000      215.000000   165.000000  161.000000   163.000000
# mean     0.838298       43.897674   840.575758   21.792391   121.009939
# std      0.561802       48.695302  1270.341831   11.664156    30.739189
# min      0.000000        1.000000     0.000000    0.000000     0.000000
# 25%      0.500000       11.500000    67.000000   13.800000   112.635000
# 50%      1.000000       25.000000   289.000000   22.410000   128.630000
# 75%      1.000000       56.000000   954.000000   29.300000   137.550000
# max      2.000000      220.000000  6283.000000   58.500000   190.240000
#
#           Wickets  Bowling_average     Economy  Bowling_Strike_Rate  \
# count  140.000000       135.000000  143.000000           119.000000
# mean    31.485714        32.907185    8.223182            24.686134
# std     36.872420        18.191441    1.223541            12.982049
# ...

# %%
data.isna().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
# ...

# %% [markdown]
# seggrigating The Data- capped batters
# We have kept the batting parameters to restrict the Analysis for batter specific tendencies

# %%
batters=data.loc[(data['Player_Type']=='Batter')]

# %%
batters_new= batters.loc[(data['Capped']==1)]

# %%
 capped_batters=batters_new[['Player Name',	
                            'Team',
                             'Nationality', 
                            'Matches_Played',
                           'Runs',
                           'Average',
                           'Strike_Rate']]

# %%
 capped_batters  #here we get the batters information of capped players
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3      Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4     Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
# 5       Robin Uthappa    Chenai       Indian           193.0  4722.0    27.94
# 6           Jason Roy    Gujarat    Overseas            13.0   329.0    29.91
# 7    Devdutt Padikkal  Rajasthan      Indian            29.0   884.0    31.57
# 8         Priyam Garg  Hyderabad      Indian            19.0   205.0    14.64
# 12     Rahul Tripathi  Hyderabad      Indian            62.0  1385.0    26.13
# 13      Aiden Markram  Hyderabad    Overseas             6.0   146.0    29.30
# ...

# %% [markdown]
# seggrigating The Data-capped wicket. We have kept the recods of keeping parameters but it not necessary to take a bowling parameters for wicket keepers.

# %%
data.head(2)
# Out:
#       Player Name     Team Nationality Player_Type  Capped  Matches_Played  \
# 0  Shikhar Dhawan   Punjab      Indian      Batter       1           192.0
# 1   Shreyas Iyer   Kolkata      Indian      Batter       1            87.0
#
#      Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 0  5783.0    34.63       126.60      4.0             16.5     8.25
# 1  2375.0    31.67       123.96      NaN              NaN      NaN
#
#    Bowling_Strike_Rate  Catches  Run_outs  Stumps
# 0                 12.0      NaN       NaN     NaN
# 1                  NaN      NaN       NaN     NaN

# %%
keepers=data.loc[(data['Player_Type']=='Keeper')]

# %%
keepers_new=keepers.loc[(data['Capped']==1)]

# %%
capped_keepers=keepers_new[['Player Name',	
                            'Team',
                             'Nationality', 
                            'Matches_Played',
                           'Runs',
                           'Average',
                           'Strike_Rate',
                            'Catches',
                            'Run_outs',
                            'Stumps'
    
]]

# %%
capped_keepers
# Out:
#            Player Name       Team Nationality  Matches_Played    Runs  \
# 105    Quinton De Kock    Lucknow    Overseas            77.0  2256.0
# 106      Ambati Rayudu    Chennai      Indian           175.0  3916.0
# 107       Ishan Kishan     Mumbai      Indian            61.0  1452.0
# 108     Jonny Bairstow     Punjab    Overseas            28.0  1038.0
# 109     Dinesh Karthik  Bangalore      Indian           213.0  4046.0
# 110   Nicholas Pooran   Hyderabad    Overseas            33.0   606.0
# 111          KS Bharat      Delhi      Indian             8.0   191.0
# 112         Anuj Rawat  Bangalore      Indian             1.0     0.0
# 113  Prabhsimran Singh     Punjab      Indian             5.0    50.0
# 114   Sheldon Jackson     Kolkata    Overseas             4.0    38.0
# 117      Sam Billings     Kolkata    Overseas            22.0   334.0
# 118   Wridhhiman Saha     Gujarat      Indian           133.0  2110.0
# ...

# %% [markdown]
# seggrigating The Data- capped Allrounders
# We have kept the batting & bowling parameters for the allrounders to Analyze all round performance.

# %%
Allrounders=data.loc[(data['Player_Type']=='Allrounder')]

# %%
Allrounders_new=Allrounders.loc[(data['Capped']==1)]

# %%
 capped_allrounders=Allrounders_new[['Player Name',	
                            'Team',
                             'Nationality', 
                            'Matches_Played',
                           'Runs',
                           'Average',
                           'Strike_Rate',
                            'Wickets',
                           'Bowling_average',
                           'Economy',
                           'Bowling_Strike_Rate'    ]]

# %%
capped_allrounders  #showing capped allrounders
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
# 130          Nitish Rana     Kolkata      Indian            77.0  1820.0
# 131          Jason Holder    Lucknow    Overseas            26.0   189.0
# 132         Harshal Patel  Bangalore      Indian            63.0   187.0
# 133          Deepak Hooda    Lucknow      Indian            80.0   785.0
# 135     Washington Sundar  Hyderabad      Indian            42.0   217.0
# 136         Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 137        Mitchell Marsh      Delhi    Overseas            21.0   225.0
# 138           Riyan Parag  Rajasthan      Indian            30.0   339.0
# 139      Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# ...

# %% [markdown]
# CLEANING THE DATA BY MAKING THE NULL OR NAN VALUE 0

# %%
capped_batters=capped_batters.fillna(0)   #fill Nane value to 0 for cleaning
capped_keepers=capped_keepers.fillna(0)
capped_allrounders=capped_allrounders.fillna(0)

# %%
print(capped_batters.isna().sum())
print(capped_keepers.isna().sum())
print(capped_allrounders.isna().sum())
# Out:
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# Catches           0
# Run_outs          0
# Stumps            0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64

# %% [markdown]
# ALL THE DATA ARE CLEANED.

# %% [markdown]
# NOW , FOR THE ANALYZING THE BATTERS DATA. SO THAT IT MAKES EASY TO PICKS THE HIGH RATING PLAYERS WITH MORE PRICE.

# %%
top_batters=capped_batters.loc[(capped_batters['Average']>=32.0)]

# %%
#sorting the data in decending order with respect to their parameter

top_batters_average=top_batters.sort_values('Average', ascending=False)
top_batters_Strike_rate=top_batters.sort_values('Strike_Rate', ascending=False)
top_batters_runs=top_batters.sort_values('Runs', ascending=False)
top_batters_matches_played=top_batters.sort_values('Matches_Played', ascending=False)

# %%
top_batters_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 212       136.38
# 231       132.13
# 19        139.97
# 207       131.27
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51

# %%
top_batters_Strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 231       132.13
# 207       131.27
# 2         131.09
# 208       129.95
# 0         126.60

# %%
top_batters_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 212       136.38
# 2         131.09
# 26        136.51
# 207       131.27
# 231       132.13

# %%
top_batters_matches_played
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 2         131.09
# 212       136.38
# 26        136.51
# 207       131.27
# 231       132.13

# %% [markdown]
# FORM OUR ANALYSIS WE MUST TOOK THESE PLAYERS AS A TOP BATTERS
# 1. DAVID WARNER
# 2. KL RAHUL
# 3.VIRAT KOHLI

# %% [markdown]
# ANALYZING THE ALLROUNDER DATA FOR BEST ALLROUNDER
# WE HAVE CONVERSE OUR ANALYSIS BY MAKING THE STRIKE RATE MORE THAN OR EQUAL TO 140.

# %%
top_allrounder= capped_allrounders.loc[(capped_allrounders['Strike_Rate']>=140.0)]

# %%
top_allrounder_average=top_allrounder.sort_values('Average', ascending=False)
top_allrounder_strike_rate=top_allrounder.sort_values('Strike_Rate', ascending=False)
top_allrounder_run=top_allrounder.sort_values('Runs', ascending=False)
top_allrounder_matches=top_allrounder.sort_values('Matches_Played', ascending=False)
top_allrounder_bowling_average=top_allrounder.sort_values('Bowling_average', ascending=True)
top_allrounder_bowling_strike_rate=top_allrounder.sort_values('Bowling_Strike_Rate', ascending=False)
top_allrounder_bowling_wicket=top_allrounder.sort_values('Wickets', ascending=False)
top_allrounder_bowling_economy=top_allrounder.sort_values('Economy', ascending=True)
#top_allrounder_bowling_matches=top_allrounder.sort_values('Bowling_average ', ascending=False)

# %%
top_allrounder_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrounder_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
#
# ...

# %%
top_allrounder_run
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrounder_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrounder_bowling_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
#
# ...

# %%
top_allrounder_bowling_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrounder_bowling_wicket
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrounder_bowling_economy
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
#
# ...

# %% [markdown]
# FROM THE ABOVE ANALYSIS WE FIND THE BEST ALLROUNDERS ARE
#
# 1) Andre Russell
# 2)Sunil Narine
# 3) Hardik Pandya
# 4) Glen Maxwell

# %% [markdown]
# ANALYZING THE KEEPER DATA FOR BEST KEEPER WE HAVE CONVERSE OUR ANALYSIS BY MAKING THE AVERAGE MORE THAN OR EQUAL TO 25.

# %%
top_keeper=capped_keepers.loc[(capped_keepers['Average']>=25)]

# %%
top_keeper_average=top_keeper.sort_values('Average', ascending=False)
top_keeper_strike_rate=top_keeper.sort_values('Strike_Rate', ascending=False)
top_keeper_runs=top_keeper.sort_values('Runs', ascending=False)
top_keeper_matches=top_keeper.sort_values('Matches_Played', ascending=False)
top_keeper_catches=top_keeper.sort_values('Catches', ascending=False)
top_keeper_runouts=top_keeper.sort_values('Run_outs', ascending=False)
top_keeper_stumps=top_keeper.sort_values('Stumps', ascending=False)

# %%
 top_keeper_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 108       142.20     18.0       1.0     4.0
# ...

# %%
top_keeper_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 219       150.00     34.0       3.0     1.0
# ...

# %%
top_keeper_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keeper_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keeper_catches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keeper_runouts
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keeper_stumps
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %% [markdown]
# FROM THE ANALYSIS WE FIND THAT THE TOP NUMBER WICKET KEEPER ARE:
# 1. MS DHONI
# 2. DINESH KARTIK
# 3. RISHAV PANTH

# %% [markdown]
# 2.VISULIZATION OF THE OUT ANALYSIS

# %%
#visulization of batters data
#the plot show each of the batters strike rate
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Strike_Rate', data=top_batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
#now the plot show the batters average 
plt.figure(figsize=(20,20))
sns.barplot(x='Player Name', y='Average', data=top_batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
#now the plot show the batters Runs
plt.figure(figsize=(20,20))
sns.barplot(x='Player Name', y='Runs', data=top_batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
#now the plot show the batters matches played
plt.figure(figsize=(20,20))
sns.barplot(x='Player Name', y='Matches_Played', data=top_batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %% [markdown]
# IN A SIMILAR WAY, WE CAN VISUALISE THE ANALYZE DATA AS TOP KEEPESE , TOP ALLROUNDER , TOP BOWLERS AND SO ON.

# %% [markdown]
# FORMING OURS BEST 11 FOR THE CAMPAIGN BASED ON ABOVE ANALYSIS.

# %% [markdown]
#   1. We will consider the number of players from each category that the t20 world cup winning and the last year's IPL winning team played in their Final matches.

# %% [markdown]
# 2. The australia squad consisted of - 3 Batters, 3 Allrounders, 4 Bowlers with 1 spin option and 1 wicket keeper.

# %% [markdown]
# 3.The chennai Squad Consisted of -4 Batters, 3 Allrounders , 3 Bowlers and 1 Wicket Keeper.

# %% [markdown]
# 4.For our final analysis we will consider the ratio of player in the best 11 as follows.
#
# 1) 3 Batters
# 2) 3 all rounders
# 3) 4 Bowlers with 2 Spin Options
# 4) 1 Wicket Keeper

# %%
#batters for the final 11 - Kl Rahul , Virat Kohli, david Warner
#here we are storing the value of each player in a seprate Data frame to use for displaying using the bar plot.
top_batters.reset_index(drop=True)
matches_values= [top_batters.iloc[6]['Matches_Played'], top_batters.iloc[2]['Matches_Played'], top_batters.iloc[5]['Matches_Played']]
runs_values= [top_batters.iloc[6]['Runs'], top_batters.iloc[2]['Runs'], top_batters.iloc[5]['Runs']]
average_values= [top_batters.iloc[6]['Average'], top_batters.iloc[2]['Average'], top_batters.iloc[5]['Average']]
strike_rate_values= [top_batters.iloc[6]['Strike_Rate'], top_batters.iloc[2]['Strike_Rate'], top_batters.iloc[5]['Strike_Rate']]
Labels=['KL Rahul','David Warner','Virat Kohli']

# %%
fig,axes= plt.subplots(2,2, figsize=(10,10))
axes[0][0].set_title('Matches_Played')
axes[0][1].set_title('Runs in the ipl career')
axes[1][0].set_title('Strike rate')
axes[1][1].set_title('Average')

sns.barplot(x=Labels, y=matches_values,ax=axes[0][0])
sns.barplot(x=Labels, y=runs_values,ax=axes[0][1])
sns.barplot(x=Labels, y=average_values,ax=axes[1][0])
sns.barplot(x=Labels, y=strike_rate_values,ax=axes[1][1])
# Out:
# <AxesSubplot:title={'center':'Average'}>

# %%
 #Allrounders for final 11 Andre Russel, Sunil Narayan, Hardik Pandey
top_allrounder.reset_index(drop=True)
matches_values= [top_allrounder.iloc[5]['Matches_Played'], top_allrounder.iloc[9]['Matches_Played'], top_allrounder.iloc[6]['Matches_Played']]
runs_values= [top_allrounder.iloc[5]['Runs'], top_allrounder.iloc[9]['Runs'], top_allrounder.iloc[6]['Runs']]
average_values= [top_allrounder.iloc[5]['Average'], top_allrounder.iloc[9]['Average'], top_allrounder.iloc[6]['Average']]
strike_rate_values= [top_allrounder.iloc[5]['Strike_Rate'], top_allrounder.iloc[9]['Strike_Rate'], top_allrounder.iloc[6]['Strike_Rate']]
bowling_strike_rate_values= [top_allrounder.iloc[5]['Bowling_Strike_Rate'], top_allrounder.iloc[9]['Bowling_Strike_Rate'], top_allrounder.iloc[6]['Bowling_Strike_Rate']]
bowling_average_values= [top_allrounder.iloc[5]['Bowling_average'], top_allrounder.iloc[9]['Bowling_average'], top_allrounder.iloc[6]['Bowling_average']]
wicket_values= [top_allrounder.iloc[5]['Wickets'], top_allrounder.iloc[9]['Wickets'], top_allrounder.iloc[6]['Wickets']]
economy_values= [top_allrounder.iloc[5]['Economy'], top_allrounder.iloc[9]['Economy'], top_allrounder.iloc[6]['Economy']]

Labels=['Andre Russel', 'Sunil Narine', 'Hardik Pandya']

# %%
fig,axes= plt.subplots(4,2, figsize=(20,20))
axes[0][0].set_title('Matches')
axes[0][1].set_title('Runs')
axes[1][0].set_title('Strike rate')
axes[1][1].set_title('Average')
axes[2][0].set_title('Bowling strike rate')
axes[2][1].set_title('Bowling Average')
axes[3][0].set_title('Wickets')
axes[3][1].set_title('Economy')

sns.barplot(x=Labels, y=matches_values,ax=axes[0][0])
sns.barplot(x=Labels, y=runs_values,ax=axes[0][1])
sns.barplot(x=Labels, y=average_values,ax=axes[1][0])
sns.barplot(x=Labels, y=strike_rate_values,ax=axes[1][1])
sns.barplot(x=Labels, y= bowling_strike_rate_values,ax=axes[2][0])
sns.barplot(x=Labels, y=bowling_average_values,ax=axes[2][1])
sns.barplot(x=Labels, y=wicket_values,ax=axes[3][0])
sns.barplot(x=Labels, y=economy_values,ax=axes[3][1])
# Out:
# <AxesSubplot:title={'center':'Economy'}>

# %%
#similarly wicket keeper for final 11- Ms Dhoni

matches_values=[top_keeper.iloc[8]['Matches_Played'],top_keeper.iloc[8]['Runs']]
average_values=[top_keeper.iloc[8]['Average'],top_keeper.iloc[8]['Strike_Rate']]
keeping_values=[top_keeper.iloc[8]['Catches'],top_keeper.iloc[8]['Stumps'],top_keeper.iloc[8]['Run_outs']]

Labels1=['Matches_Played','Runs']
Labels2=['Average','Strike Rate']
Labels3=['Catches','Stumps','Run_Outs']

fig, axes= plt.subplots(1,3,figsize=(20,10))
axes[0].set_title('matches & runs')
axes[1].set_title('Average & strike Rate')
axes[2].set_title('Keeping stats')

sns.barplot(x=Labels1,y=matches_values,ax=axes[0])
sns.barplot(x=Labels2,y=average_values,ax=axes[1])
sns.barplot(x=Labels3,y=keeping_values,ax=axes[2])
# Out:
# <AxesSubplot:title={'center':'Keeping stats'}>

# %% [markdown]
# Now player for the final 11 but with out bowler.It is because the CSV data is not readable for player type == Bowler. So we make test team with out bowler due to the crash of Data.

# %%
batter1=top_batters.loc[(top_batters['Player Name']=='KL Rahul ')]
batter2=top_batters.loc[(top_batters['Player Name']=='David Warner ')]
batter3=top_batters.loc[(top_batters['Player Name']=='Virat Kohli')]

allrounder1=top_allrounder.loc[(top_allrounder['Player Name']=='Andre Russell')]
allrounder2=top_allrounder.loc[(top_allrounder['Player Name']=='Sunil Narine ')]
allrounder3=top_allrounder.loc[(top_allrounder['Player Name']=='Hardik Pandya')]

keeper=top_keeper.loc[(top_keeper['Player Name']=='MS Dhoni')]

# %%
final=[batter1,batter2,batter3,allrounder1,allrounder2,allrounder3,keeper]
final_team=pd.concat(final)
final_team=final_team.drop(labels=['Matches_Played','Average','Runs', 
                                   'Strike_Rate','Wickets','Bowling_average',
                                   'Economy','Bowling_Strike_Rate','Run_outs',
                                   'Catches','Stumps'], axis=1)
final_team.reset_index(drop=True)
# Out:
#      Player Name       Team Nationality
# 0      KL Rahul     Lucknow      Indian
# 1  David Warner       Delhi    Overseas
# 2    Virat Kohli  Bangalore      Indian
# 3  Andre Russell    Kolkata    Overseas
# 4  Sunil Narine     Kolkata    Overseas
# 5  Hardik Pandya    Gujarat      Indian
# 6       MS Dhoni    Chennai      Indian

# %% [markdown]
# Here is the 7 team member and 4 will be Bowler.
